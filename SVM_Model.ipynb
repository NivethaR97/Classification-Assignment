# 28           0.943699           0.962573           0.962264
# 29           0.962264           1.000000           0.981031
# 30           0.981014           0.981217           1.000000
# 31           0.943699           0.962573           0.981031
# 32           0.943699           0.962573           0.962264
# 33           0.962264           1.000000           0.981031
# 34           0.981014           0.981217           1.000000
# 35           0.943699           0.962573           0.981031
# 36           0.943699           0.962573           0.962264
# 37           0.962264           1.000000           0.981031
# 38           0.981014           0.981217           1.000000
# 39           0.943699           0.962573           0.981031
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.981217         0.962607        0.011869               31
# 1            1.000000         0.985110        0.018240                3
# 2            0.981217         0.984801        0.014284                5
# 3            1.000000         0.988767        0.009174                1
# 4            0.981217         0.962607        0.011869               31
# 5            1.000000         0.985110        0.018240                3
# 6            0.981217         0.984801        0.014284                5
# 7            1.000000         0.988767        0.009174                1
# 8            0.981217         0.962607        0.011869               31
# 9            1.000000         0.981316        0.016652               13
# 10           0.981217         0.981309        0.011614               21
# 11           1.000000         0.970065        0.022459               23
# 12           0.981217         0.962607        0.011869               31
# 13           1.000000         0.981316        0.016652               13
# 14           0.981217         0.981309        0.011614               21
# 15           1.000000         0.970065        0.022459               23
# 16           0.981217         0.962607        0.011869               31
# 17           1.000000         0.981316        0.016652               13
# 18           0.981217         0.981346        0.011613                7
# 19           0.981217         0.970018        0.015021               25
# 20           0.981217         0.962607        0.011869               31
# 21           1.000000         0.981316        0.016652               13
# 22           0.981217         0.981346        0.011613                7
# 23           0.981217         0.970018        0.015021               25
# 24           0.981217         0.962607        0.011869               31
# 25           1.000000         0.981316        0.016652               13
# 26           0.981217         0.981346        0.011613                7
# 27           0.981217         0.970018        0.015021               25
# 28           0.981217         0.962607        0.011869               31
# 29           1.000000         0.981316        0.016652               13
# 30           0.981217         0.981346        0.011613                7
# 31           0.981217         0.970018        0.015021               25
# 32           0.981217         0.962607        0.011869               31
# 33           1.000000         0.981316        0.016652               13
# 34           0.981217         0.981346        0.011613                7
# 35           0.981217         0.970018        0.015021               25
# 36           0.981217         0.962607        0.011869               31
# 37           1.000000         0.981316        0.016652               13
# 38           0.981217         0.981346        0.011613                7
# 39           0.981217         0.970018        0.015021               25

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
age_input=float(input("enter age:"))
bp_input=float(input("enter bp:"))
al_input=int(input("enter al:"))
su_input=int(input("enter su:"))
bgr_input=float(input("enter bgr:"))
bu_input=float(input("enter bu:"))
sc_input=float(input("enter sc:"))
sod_input=float(input("enter sod:"))
pot_input=float(input("enter pot:"))
hrmo_input=float(input("enter hrmo:"))
pcv_input=float(input("enter pcv:"))
wc_input=float(input("enter wc:"))
rc_input=float(input("enter rc:"))
sg_input=input("enter sg:")
rbc_input=input("enter rbc:")
pc_input=input("enter pc:")
pcc_input=input("enter pcc:")
ba_input=input("enter ba:")
htn_input=input("enter htn:")
dm_input=input("enter dm:")
cad_input=input("enter cad:")
appet_input=input("enter appet:")
pe_input=input("enter pe:")
ane_input=input("enter ane:")
# Out:
# enter age 24
# enter bp 108
# enter al 3
# enter su 1
# enter bgr 140
# enter bu 24
# enter sc 0.6
# enter sod 143
# enter pot 4.5
# enter hrmo 10.6
# enter pcv 44
# enter wc 124
# enter rc 4.6
# enter sg a
# enter rbc normal
# enter pc abnormal
# enter pcc present
# enter ba notpresent
# enter htn no
# enter dm yes
# enter cad yes
# enter appet yes
# enter pe yes
# enter ane yes

# %%
Future_Prediction=grid.predict([[age_input,bp_input,al_input,su_input,bgr_input,bu_input,sc_input,sod_input,pot_input,hrmo_input,pcv_input,wc_input,rc_input,sg_input, rbc_input, pc_input,pcc_input, ba_input, htn_input,dm_input,cad_input,appet_input,pe_input,ane_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 Future_Prediction=grid.predict([[age_input,bp_input,al_input,su_input,bgr_input,bu_input,sc_input,sod_input,pot_input,hrmo_input,pcv_input,wc_input,rc_input,sg_input, rbc_input, pc_input,pcc_input, ba_input, htn_input,dm_input,cad_input,appet_input,pe_input,ane_input]])
#       2 print("Future_Prediction={}".format(Future_Prediction))
#
# File C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:597, in BaseSearchCV.predict(self, X)
#     579 """Call predict on the estimator with the best found parameters.
#     580
#     581 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     594     the best found parameters.
#     595 """
#     596 check_is_fitted(self)
# --> 597 return self.best_estimator_.predict(X)
#
# File C:\Anaconda3\Lib\site-packages\sklearn\svm\_base.py:813, in BaseSVC.predict(self, X)
#     811     y = np.argmax(self.decision_function(X), axis=1)
#     812 else:
# --> 813     y = super().predict(X)
#     814 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File C:\Anaconda3\Lib\site-packages\sklearn\svm\_base.py:428, in BaseLibSVM.predict(self, X)
#     412 def predict(self, X):
#     413     """Perform regression on samples in X.
#     414
#     415     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     426         The predicted values.
#     427     """
# --> 428     X = self._validate_for_predict(X)
#     429     predict = self._sparse_predict if self._sparse else self._dense_predict
#     430     return predict(X)
#
# File C:\Anaconda3\Lib\site-packages\sklearn\svm\_base.py:606, in BaseLibSVM._validate_for_predict(self, X)
#     603 check_is_fitted(self)
#     605 if not callable(self.kernel):
# --> 606     X = self._validate_data(
#     607         X,
#     608         accept_sparse="csr",
#     609         dtype=np.float64,
#     610         order="C",
#     611         accept_large_sparse=False,
#     612         reset=False,
#     613     )
#     615 if self._sparse and not sp.issparse(X):
#     616     X = sp.csr_matrix(X)
#
# File C:\Anaconda3\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010         array = xp.astype(array, dtype, copy=False)
#    1011     else:
# -> 1012         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013 except ComplexWarning as complex_warning:
#    1014     raise ValueError(
#    1015         "Complex data not supported\n{}\n".format(array)
#    1016     ) from complex_warning
#
# File C:\Anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:751, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     749     array = numpy.array(array, order=order, dtype=dtype)
#     750 else:
# --> 751     array = numpy.asarray(array, order=order, dtype=dtype)
#     753 # At this point array is a NumPy ndarray. We convert it to an array
#     754 # container that is consistent with the input's namespace.
#     755 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'a'
